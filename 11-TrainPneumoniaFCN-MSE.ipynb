# %%
import numpy as np
import matplotlib.pyplot as plt
from time import time
import random

from keras.models import Model
from keras.layers import Input, Flatten
from keras.layers import Conv2D, SeparableConv2D
from keras.layers import BatchNormalization, MaxPooling2D
from keras.layers import Dense, Dropout

# %%
def load_numpy():
    global X_train
    global Y_train
    global X_test 
    global Y_test  

    with open('/content/drive/MyDrive/IDEC/chest-array.npy','rb') as f:
        X_train = np.load(f)
        Y_train = np.load(f)
        X_test = np.load(f)
        Y_test = np.load(f)

    print("Read Numpy Data")

# %%
load_numpy()
# Out:
# Read Numpy Data

# %%
def conv_block(filters, inputs):
    x = SeparableConv2D(filters,
                        kernel_size=3,
                        activation='relu',
                        padding='same')(inputs)

    x = SeparableConv2D(filters,
                        kernel_size=3,
                        activation='relu',
                        padding='same')(x)

    x = BatchNormalization()(x)

    output = MaxPooling2D(pool_size=2)(x)

    return output

# %%
def dense_block(units, drop, inputs):
    x = Dense(units=units,
              activation='relu')(inputs)

    x = BatchNormalization()(x)

    output = Dropout(drop)(x)

    return output

# %%
EPOCH = 200
BATCH_SIZE = 100
RES = 180
SHAPE = (RES, RES, 3)

# %%
# Design Network

input = Input(shape=(SHAPE))

x = Conv2D(filters=16,
           kernel_size=3,
           activation='relu',
           padding='same')(input)

x = Conv2D(filters=16,
           kernel_size=3,
           activation='relu',
           padding='same')(x)

x = MaxPooling2D(pool_size=2)(x)

x = conv_block(32,x)

x = conv_block(64,x)

x = conv_block(128,x)
x = Dropout(0.2)(x)

x = conv_block(256,x)
x = Dropout(0.2)(x)

x = Flatten()(x)

x = dense_block(512, 0.7, x)
x = dense_block(128, 0.5, x)
x = dense_block(64, 0.3, x)

output = Dense(units=1,
          activation='sigmoid')(x)

model = Model(inputs=input,
              outputs=output)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 180, 180, 3)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 180, 180, 16)      448
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 180, 180, 16)      2320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 90, 90, 16)        0
# _________________________________________________________________
# separable_conv2d (SeparableC (None, 90, 90, 32)        688
# _________________________________________________________________
# separable_conv2d_1 (Separabl (None, 90, 90, 32)        1344
# _________________________________________________________________
# batch_normalization (BatchNo (None, 90, 90, 32)        128
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 45, 45, 32)        0
# _________________________________________________________________
# separable_conv2d_2 (Separabl (None, 45, 45, 64)        2400
# _________________________________________________________________
# separable_conv2d_3 (Separabl (None, 45, 45, 64)        4736
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 45, 45, 64)        256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 64)        0
# _________________________________________________________________
# separable_conv2d_4 (Separabl (None, 22, 22, 128)       8896
# _________________________________________________________________
# separable_conv2d_5 (Separabl (None, 22, 22, 128)       17664
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 22, 22, 128)       512
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 11, 11, 128)       0
# _________________________________________________________________
# dropout (Dropout)            (None, 11, 11, 128)       0
# _________________________________________________________________
# separable_conv2d_6 (Separabl (None, 11, 11, 256)       34176
# _________________________________________________________________
# separable_conv2d_7 (Separabl (None, 11, 11, 256)       68096
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 11, 11, 256)       1024
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 5, 5, 256)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 5, 5, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 6400)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               3277312
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               65664
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 128)               512
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                8256
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 64)                256
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 3,496,801
# Trainable params: 3,494,433
# Non-trainable params: 2,368
# _________________________________________________________________

# %%
# Train Network

model.compile(optimizer='adam',
              loss='mse',
              metrics=['acc'])

print("Start Train\n")

begin = time()
model.fit(x=X_train,
          y=Y_train,
          epochs=EPOCH,
          batch_size=BATCH_SIZE,
          verbose=1)
end = time()

print("Learning TIme : {:.2f}".format(end-begin))

model.save_weights('classification.h5')
# Out:
# Start Train
#
# Epoch 1/200
# 10/10 [==============================] - 9s 306ms/step - loss: 0.2428 - acc: 0.6322
# Epoch 2/200
# 10/10 [==============================] - 3s 306ms/step - loss: 0.0995 - acc: 0.8774
# Epoch 3/200
# 10/10 [==============================] - 3s 317ms/step - loss: 0.0849 - acc: 0.8926
# Epoch 4/200
# 10/10 [==============================] - 3s 316ms/step - loss: 0.0635 - acc: 0.9305
# Epoch 5/200
# 10/10 [==============================] - 3s 309ms/step - loss: 0.0487 - acc: 0.9427
# Epoch 6/200
# 10/10 [==============================] - 3s 321ms/step - loss: 0.0471 - acc: 0.9425
# Epoch 7/200
# 10/10 [==============================] - 3s 320ms/step - loss: 0.0411 - acc: 0.9425
# Epoch 8/200
# 10/10 [==============================] - 3s 310ms/step - loss: 0.0252 - acc: 0.9714
# Epoch 9/200
# 10/10 [==============================] - 3s 317ms/step - loss: 0.0374 - acc: 0.9502
# Epoch 10/200
# 10/10 [==============================] - 3s 300ms/step - loss: 0.0253 - acc: 0.9697
# Epoch 11/200
# 10/10 [==============================] - 3s 318ms/step - loss: 0.
200
# 10/10 [==============================] - 3s 320ms/step - loss: 0.0029 - acc: 0.9966
# Epoch 170/200
# 10/10 [==============================] - 3s 310ms/step - loss: 3.5280e-04 - acc: 0.9996
# Epoch 171/200
# 10/10 [==============================] - 3s 307ms/step - loss: 0.0011 - acc: 0.9988
# Epoch 172/200
# 10/10 [==============================] - 3s 312ms/step - loss: 8.3598e-04 - acc: 0.9994
# Epoch 173/200
# 10/10 [==============================] - 3s 308ms/step - loss: 0.0012 - acc: 0.9968
# Epoch 174/200
# 10/10 [==============================] - 3s 319ms/step - loss: 0.0049 - acc: 0.9932
# Epoch 175/200
# 10/10 [==============================] - 3s 309ms/step - loss: 0.0026 - acc: 0.9969
# Epoch 176/200
# 10/10 [==============================] - 3s 315ms/step - loss: 0.0039 - acc: 0.9956
# Epoch 177/200
# 10/10 [==============================] - 3s 317ms/step - loss: 0.0030 - acc: 0.9958
# Epoch 178/200
# 10/10 [==============================] - 3s 317ms/step - loss: 0.0031 - acc: 0.9963
# Epoch 179/200
# 10/10 [==============================] - 3s 321ms/step - loss: 4.6887e-04 - acc: 0.9995
# Epoch 180/200
# 10/10 [==============================] - 3s 316ms/step - loss: 0.0020 - acc: 0.9986
# Epoch 181/200
# 10/10 [==============================] - 3s 315ms/step - loss: 1.6112e-04 - acc: 1.0000
# Epoch 182/200
# 10/10 [==============================] - 3s 315ms/step - loss: 0.0014 - acc: 0.9959
# Epoch 183/200
# 10/10 [==============================] - 3s 319ms/step - loss: 0.0027 - acc: 0.9967
# Epoch 184/200
# 10/10 [==============================] - 3s 315ms/step - loss: 6.8343e-05 - acc: 1.0000
# Epoch 185/200
# 10/10 [==============================] - 3s 314ms/step - loss: 0.0024 - acc: 0.9982
# Epoch 186/200
# 10/10 [==============================] - 3s 314ms/step - loss: 5.4343e-04 - acc: 1.0000
# Epoch 187/200
# 10/10 [==============================] - 3s 320ms/step - loss: 0.0041 - acc: 0.9962
# Epoch 188/200
# 10/10 [==============================] - 3s 320ms/step - loss: 7.9213e-04 - acc: 0.9995
# Epoch 189/200
# 10/10 [==============================] - 3s 322ms/step - loss: 1.5545e-04 - acc: 1.0000
# Epoch 190/200
# 10/10 [==============================] - 3s 317ms/step - loss: 0.0013 - acc: 0.9984
# Epoch 191/200
# 10/10 [==============================] - 3s 309ms/step - loss: 0.0013 - acc: 0.9985
# Epoch 192/200
# 10/10 [==============================] - 3s 303ms/step - loss: 4.6522e-04 - acc: 0.9998
# Epoch 193/200
# 10/10 [==============================] - 3s 312ms/step - loss: 0.0011 - acc: 0.9982
# Epoch 194/200
# 10/10 [==============================] - 3s 321ms/step - loss: 0.0019 - acc: 0.9975
# Epoch 195/200
# 10/10 [==============================] - 3s 316ms/step - loss: 8.3833e-04 - acc: 0.9996
# Epoch 196/200
# 10/10 [==============================] - 3s 320ms/step - loss: 6.5245e-04 - acc: 0.9989
# Epoch 197/200
# 10/10 [==============================] - 3s 319ms/step - loss: 4.1113e-04 - acc: 0.9998
# Epoch 198/200
# 10/10 [==============================] - 3s 316ms/step - loss: 0.0078 - acc: 0.9907
# Epoch 199/200
# 10/10 [==============================] - 3s 313ms/step - loss: 6.9900e-05 - acc: 1.0000
# Epoch 200/200
# 10/10 [==============================] - 3s 324ms/step - loss: 5.4723e-04 - acc: 1.0000
# Learning TIme : 635.31

# %%
score = model.evaluate(x=X_test,
                       y=Y_test,
                       verbose=1)
print("Final Loss : {:.2f}".format(score[0]))
print("Final Accuracy : {:.2f}".format(score[1]))
# Out:
# 7/7 [==============================] - 1s 39ms/step - loss: 0.1464 - acc: 0.8500
# Final Loss : 0.15
# Final Accuracy : 0.85

# %%
total = len(X_test)
pick = random.sample(range(0,total),1)
print(pick)

plt.imshow(X_test[pick].reshape(RES, RES, 3))
img = X_test[pick].reshape(1, RES, RES, 3)
pred = model.predict(img)

print("Label :", Y_test[pick])
print("Pred :", pred)
# Out:
# [184]
# Label : [1.]
# Pred : [[0.99997175]]
