# %%
import numpy as np
import matplotlib.pyplot as plt
from time import time
import random

from keras.models import Model
from keras.layers import Input, Flatten
from keras.layers import Conv2D, SeparableConv2D
from keras.layers import BatchNormalization, MaxPooling2D
from keras.layers import Dense, Dropout

# %%
def load_numpy():
    global X_train
    global Y_train
    global X_test 
    global Y_test  

    with open('/content/drive/MyDrive/IDEC/chest-array.npy','rb') as f:
        X_train = np.load(f)
        Y_train = np.load(f)
        X_test = np.load(f)
        Y_test = np.load(f)

    print("Read Numpy Data")

# %%
load_numpy()
# Out:
# Read Numpy Data

# %%
def conv_block(filters, inputs):
    x = SeparableConv2D(filters,
                        kernel_size=3,
                        activation='relu',
                        padding='same')(inputs)

    x = SeparableConv2D(filters,
                        kernel_size=3,
                        activation='relu',
                        padding='same')(x)

    x = BatchNormalization()(x)

    output = MaxPooling2D(pool_size=2)(x)

    return output

# %%
def dense_block(units, drop, inputs):
    x = Dense(units=units,
              activation='relu')(inputs)

    x = BatchNormalization()(x)

    output = Dropout(drop)(x)

    return output

# %%
EPOCH = 200
BATCH_SIZE = 100
RES = 180
SHAPE = (RES, RES, 3)

# %%
# Design Network

input = Input(shape=(SHAPE))

x = Conv2D(filters=16,
           kernel_size=3,
           activation='relu',
           padding='same')(input)

x = Conv2D(filters=16,
           kernel_size=3,
           activation='relu',
           padding='same')(x)

x = MaxPooling2D(pool_size=2)(x)

x = conv_block(32,x)

x = conv_block(64,x)

x = conv_block(128,x)
x = Dropout(0.2)(x)

x = conv_block(256,x)
x = Dropout(0.2)(x)

x = Flatten()(x)

x = dense_block(512, 0.7, x)
x = dense_block(128, 0.5, x)
x = dense_block(64, 0.3, x)

output = Dense(units=1,
          activation='sigmoid')(x)

model = Model(inputs=input,
              outputs=output)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 180, 180, 3)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 180, 180, 16)      448
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 180, 180, 16)      2320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 90, 90, 16)        0
# _________________________________________________________________
# separable_conv2d (SeparableC (None, 90, 90, 32)        688
# _________________________________________________________________
# separable_conv2d_1 (Separabl (None, 90, 90, 32)        1344
# _________________________________________________________________
# batch_normalization (BatchNo (None, 90, 90, 32)        128
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 45, 45, 32)        0
# _________________________________________________________________
# separable_conv2d_2 (Separabl (None, 45, 45, 64)        2400
# _________________________________________________________________
# separable_conv2d_3 (Separabl (None, 45, 45, 64)        4736
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 45, 45, 64)        256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 64)        0
# _________________________________________________________________
# separable_conv2d_4 (Separabl (None, 22, 22, 128)       8896
# _________________________________________________________________
# separable_conv2d_5 (Separabl (None, 22, 22, 128)       17664
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 22, 22, 128)       512
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 11, 11, 128)       0
# _________________________________________________________________
# dropout (Dropout)            (None, 11, 11, 128)       0
# _________________________________________________________________
# separable_conv2d_6 (Separabl (None, 11, 11, 256)       34176
# _________________________________________________________________
# separable_conv2d_7 (Separabl (None, 11, 11, 256)       68096
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 11, 11, 256)       1024
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 5, 5, 256)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 5, 5, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 6400)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               3277312
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               65664
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 128)               512
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                8256
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 64)                256
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 3,496,801
# Trainable params: 3,494,433
# Non-trainable params: 2,368
# _________________________________________________________________

# %%
# Train Network

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['acc'])

print("Start Train\n")

begin = time()
model.fit(x=X_train,
          y=Y_train,
          epochs=EPOCH,
          batch_size=BATCH_SIZE,
          verbose=1)
end = time()

print("Learning TIme : {:.2f}".format(end-begin))

model.save_weights('classification.h5')
# Out:
# Start Train
#
# Epoch 1/200
# 10/10 [==============================] - 9s 314ms/step - loss: 0.7141 - acc: 0.6241
# Epoch 2/200
# 10/10 [==============================] - 3s 309ms/step - loss: 0.2874 - acc: 0.8826
# Epoch 3/200
# 10/10 [==============================] - 3s 314ms/step - loss: 0.2502 - acc: 0.9132
# Epoch 4/200
# 10/10 [==============================] - 3s 315ms/step - loss: 0.1975 - acc: 0.9257
# Epoch 5/200
# 10/10 [==============================] - 3s 320ms/step - loss: 0.1964 - acc: 0.9229
# Epoch 6/200
# 10/10 [==============================] - 3s 313ms/step - loss: 0.1285 - acc: 0.9441
# Epoch 7/200
# 10/10 [==============================] - 3s 319ms/step - loss: 0.1020 - acc: 0.9678
# Epoch 8/200
# 10/10 [==============================] - 3s 314ms/step - loss: 0.1068 - acc: 0.9660
# Epoch 9/200
# 10/10 [==============================] - 3s 306ms/step - loss: 0.1105 - acc: 0.9498
# Epoch 10/200
# 10/10 [==============================] - 3s 318ms/step - loss: 0.0918 - acc: 0.9738
# Epoch 11/200
# 10/10 [==============================] - 3s 322ms/step - loss: 0.0852 - acc: 0.9710
# Epoch 12/200
# 10/10 [==============================] - 3s 314ms/step - loss: 0.0781 - acc: 0.9755
# Epoch 13/200
# 10/10 [==============================] - 3s 323ms/step - loss: 0.1271 - acc: 0.9460
# Epoch 14/200
# 10/10 [==============================] - 3s 321ms/step - loss: 0.0690 - acc: 0.9767
# Epoch 15/200
# 10/10 [==============================] - 3s 301ms/step - loss: 0.0543 - acc: 0.9799
# Epoch 16/200
# 10/10 [==============================] - 3s 312ms/step - loss: 0.0610 - acc: 0.9789
# Epoch 17/200
# 10/10 [==============================] - 3s 320ms/step - loss: 0.0535 - acc: 0.9783
# Epoch 18/200
# 10/10 [==============================] - 3s 312ms/step - loss: 0.0376 - acc: 0.9849
# Epoch 19/200
# 10/10 [==============================] - 3s 313ms/step - loss: 0.0260 - acc: 0.9936
# Epoch 20/200
# 10/10 [==============================] - 3s 319ms/step - loss: 0.0276 - acc: 0.9933
# Epoch 21/200
# 10/10 [==============================] - 3s 311ms/step - loss: 0.0244 - acc: 0.9923
# Epoch 22/200
# 10/10 [==============================] - 3s 320ms/step - loss: 0.0195 - acc: 0.9973
# Epoch 23/200
# 10/10 [==============================] - 3s 312ms/step - loss: 0.0137 - acc: 0.9968
# Epoch 24/200
# 10/10 [==============================] - 3s 308ms/step - loss: 0.0340 - acc: 0.9859
# Epoch 25/200
# 10/10 [==============================] - 3s 311ms/step - loss: 0.0224 - acc: 0.9942
# Epoch 26/200
# 10/10 [==============================] - 3s 313ms/step - loss: 0.0166 - acc: 0.9957
# Epoch 27/200
# 10/10 [==============================] - 3s 307ms/step - loss: 0.0237 - acc: 0.9932
# Epoch 28/200
# 10/10 [==============================] - 3s 305ms/step - loss: 0.0207 - acc: 0.9931
# Epoch 29/200
# 10/10 [==============================] - 3s 308ms/step - loss: 0.0331 - acc: 0.9881
# Epoch 30/200
# 10/10 [==============================] - 3s 317ms/step - loss: 0.0135 - acc: 0.9976
# Epoch 31/200
# 10/10 [==============================] - 3s 309ms/step - loss: 0.0124 - acc: 0.9953
# Epoch 32/200
# 10/10 [==============================] - 3s 321ms/step - loss: 0.0121 - acc: 0.9955
# Epoch 33/200
# 10/10 [==============================] - 3s 317ms/step - loss: 0.0183 - acc: 0.9938
# Epoch 34/200
# 10/10 [==============================] - 3s 309ms/step - loss: 0.0374 - acc: 0.9834
# Epoch 35/200
# 10/10 [==============================] - 3s 312ms/step - loss: 0.0208 - acc: 0.9921
# Epoch 36/200
# 10/10 [==============================] - 3s 318ms/step - loss: 0.0193 - acc: 0.9960
# Epoch 37/200
# 10/10 [==============================] - 3s 321ms/step - loss: 0.0133 - acc: 0.9953
# Epoch 38/200
# 10/10 [==============================] - 3s 316ms/step - loss: 0.0181 - acc: 0.9954
# Epoch 39/200
# 10/10 [==============================] - 3s 316ms/step - loss: 0.0132 - acc: 0.9939
# Epoch 40/200
# 10/10 [==============================] - 3s 314ms/step - loss: 0.0116 - acc: 0.9939
# Epoch 41/200
# 10/10 [==============================] - 3s 313ms/step - loss: 0.0089 - acc: 0.9979
# Epoch 42/200
# 10/10 [==============================] - 3s 312ms/step - loss: 0.0042 - acc: 0.9993
# Epoch 43/200
# 10/10 [==============================] - 3s 322ms/step - loss: 0.0058 - acc: 0.9989
# Epoch 44/200
# 10/10 [==============================] - 3s 319ms/step - loss: 0.0079 - acc: 0.9982
# Epoch 45/200
# 10/10 [==============================] - 3s 317ms/step - loss: 0.0041 - acc: 0.9996
# Epoch 46/200
# 10/10 [==============================] - 3s 301ms/step - loss: 0.0073 - acc: 0.9972
# Epoch 47/200
# 10/10 [==============================] - 3s 310ms/step - loss: 0.0075 - acc: 0.9990
# Epoch 48/200
# 10/10 [==============================] - 3s 316ms/step - loss: 0.0056 - acc: 0.9978
# Epoch 49/200
# 10/10 [==============================] - 3s 318ms/step - loss: 0.0055 - acc: 0.9988
# Epoch 50/200
# 10/10 [==============================] - 3s 313ms/step - loss: 0.0067 - acc: 0.9983
# Epoch 51/200
# 10/10 [==============================] - 3s 305ms/step - loss: 0.0148 - acc: 0.9964
# Epoch 52/200
# 10/10 [==============================] - 3s 319ms/step - loss: 0.0076 - acc: 0.9976
# Epoch 53/200
# 10/10 [==============================] - 3s 315ms/step - loss: 0.0100 - acc: 0.9978
# Epoch 54/200
# 10/10 [==============================] - 3s 316ms/step - loss: 0.0046 - acc: 0.9994
# Epoch 55/200
# 10/10 [==============================] - 3s 313ms/step - loss: 0.0169 - acc: 0.9935
# Epoch 56/200
# 10/10 [==============================] - 3s 318ms/step - loss: 0.0142 - acc: 0.9966
# Epoch 57/200
# 10/10 [==============================] - 3s 318ms/step - loss: 0.0175 - acc: 0.9940
# Epoch 58/200
# 10/10 [==============================] - 3s 307ms/step - loss: 0.0162 - acc: 0.9943
# Epoch 59/200
# 10/10 [==============================] - 3s 314ms/step - loss: 0.0095 - acc: 0.9969
# Epoch 60/200
# 10/10 [==============================] - 3s 320ms/step - loss: 0.0057 - acc: 1.0000
# Epoch 61/200
# 10/10 [==============================] - 3s 319ms/step - loss: 0.0091 - acc: 0.9967
# Epoch 62/200
# 10/10 [==============================] - 3s 323ms/step - loss: 0.0033 - acc: 0.9986
# Epoch 63/200
# 10/10 [==============================] - 3s 320ms/step - loss: 0.0062 - acc: 0.9991
# Epoch 64/200
# 10/10 [==============================] - 3s 317ms/step - loss: 0.0070 - acc: 0.9989
# Epoch 65/200
# 10/10 [==============================] - 3s 307ms/step - loss: 0.0229 - acc: 0.9909
# Epoch 66/200
# 10/10 [==============================] - 3s 315ms/step - loss: 0.0227 - acc: 0.9946
# Epoch 67/200
# 10/10 [==============================] - 3s 317ms/step - loss: 0.0186 - acc: 0.9909
# Epoch 68/200
# 10/10 [==============================] - 3s 325ms/step - loss: 0.0065 - acc: 0.9985
# Epoch 69/200
# 10/10 [==============================] - 3s 315ms/step - loss: 0.0077 - acc: 0.9984
# Epoch 70/200
# 10/10 [==============================] - 3s 320ms/step - loss: 0.0098 - acc: 0.9965
# Epoch 71/200
# 10/10 [==============================] - 3s 314ms/step - loss: 0.0199 - acc: 0.9942
# Epoch 72/200
# 10/10 [==============================] - 3s 322ms/step - loss: 0.0081 - acc: 0.9959
# Epoch 73/200
# 10/10 [==============================] - 3s 310ms/step - loss: 0.0038 - acc: 1.0000
# Epoch 74/200
# 10/10 [==============================] - 3s 314ms/step - loss: 0.0067 - acc: 0.9974
# Epoch 75/200
# 10/10 [==============================] - 3s 312ms/step - loss: 0.0013 - acc: 1.0000
# Epoch 76/200
# 10/10 [==============================] - 3s 313ms/step - loss: 0.0026 - acc: 0.9986
# Epoch 77/200
# 10/10 [==============================] - 3s 321ms/step - loss: 0.0067 - acc: 0.9937
# Epoch 78/200
# 10/10 [==============================] - 3s 311ms/step - loss: 0.0096 - acc: 0.9959
# Epoch 79/200
# 10/10 [==============================] - 3s 315ms/step - loss: 0.0036 - acc: 0.9982
# Epoch 80/200
# 10/10 [==============================] - 3s 320ms/step - loss: 0.0098 - acc: 0.9976
# Epoch 81/200
# 10/10 [==============================] - 3s 315ms/step - loss: 0.0109 - acc: 0.9942
# Epoch 82/200
# 10/10 [==============================] - 3s 323ms/step - loss: 0.0068 - acc: 0.9962
# Epoch 83/200
# 10/10 [==============================] - 3s 320ms/step - loss: 0.0062 - acc: 0.9982
# Epoch 84/200
# 10/10 [==============================] - 3s 313ms/step - loss: 0.0140 - acc: 0.9952
# Epoch 85/200
# 10/10 [==============================] - 3s 316ms/step - loss: 0.0083 - acc: 0.9984
# Epoch 86/200
# 10/10 [==============================] - 3s 299ms/step - loss: 0.0142 - acc: 0.9953
# Epoch 87/200
# 10/10 [==============================] - 3s 322ms/step - loss: 0.0076 - acc: 0.9980
# Epoch 88/200
# 10/10 [==============================] - 3s 316ms/step - loss: 0.0152 - acc: 0.9965
# Epoch 89/200
# 10/10 [==============================] - 3s 316ms/step - loss: 0.0103 - acc: 0.9967
# Epoch 90/200
# 10/10 [==============================] - 3s 311ms/step - loss: 0.0170 - acc: 0.9937
# Epoch 91/200
# 10/10 [==============================] - 3s 317ms/step - loss: 0.0096 - acc: 0.9968
# Epoch 92/200
# 10/10 [==============================] - 3s 310ms/step - loss: 0.0172 - acc: 0.9927
# Epoch 93/200
# 10/10 [==============================] - 3s 312ms/step - loss: 0.0053 - acc: 0.9984
# Epoch 94/200
# 10/10 [==============================] - 3s 314ms/step - loss: 0.0218 - acc: 0.9949
# Epoch 95/200
# 10/10 [==============================] - 3s 315ms/step - loss: 0.0042 - acc: 0.9981
# Epoch 96/200
# 10/10 [==============================] - 3s 319ms/step - loss: 0.0140 - acc: 0.9935
# Epoch 97/200
# 10/10 [==============================] - 3s 314ms/step - loss: 0.0048 - acc: 0.9990
# Epoch 98/200
# 10/10 [==============================] - 3s 308ms/step - loss: 0.0075 - acc: 0.9977
# Epoch 99/200
# 10/10 [==============================] - 3s 315ms/step - loss: 0.0066 - acc: 0.9972
# Epoch 100/200
# 10/10 [==============================] - 3s 323ms/step - loss: 0.0225 - acc: 0.9916
# Epoch 101/200
# 10/10 [==============================] - 3s 315ms/step - loss: 0.0096 - acc: 0.9971
# Epoch 102/200
# 10/10 [==============================] - 3s 299ms/step - loss: 0.0163 - acc: 0.9954
# Epoch 103/200
# 10/10 [==============================] - 3s 320ms/step - loss: 0.0131 - acc: 0.9977
# Epoch 104/200
# 10/10 [==============================] - 3s 310ms/step - loss: 0.0082 - acc: 0.9973
# Epoch 105/200
# 10/10 [==============================] - 3s 319ms/step - loss: 0.0046 - acc: 1.0000
# Epoch 106/200
# 10/10 [==============================] - 3s 323ms/step - loss: 0.0071 - acc: 0.9991
# Epoch 107/200
# 10/10 [==============================] - 3s 318ms/step - loss: 0.0017 - acc: 0.9995
# Epoch 108/200
# 10/10 [==============================] - 3s 321ms/step - loss: 0.0036 - acc: 0.9990
# Epoch 109/200
# 10/10 [==============================] - 3s 304ms/step - loss: 0.0014 - acc: 0.9995
# Epoch 110/200
# 10/10 [==============================] - 3s 316ms/step - loss: 0.0023 - acc: 0.9998
# Epoch 111/200
# 10/10 [==============================] - 3s 323ms/step - loss: 7.9372e-04 - acc: 1.0000
# Epoch 112/200
# 10/10 [==============================] - 3s 315ms/step - loss: 0.0073 - acc: 0.9973
# Epoch 113/200
# 10/10 [==============================] - 3s 315ms/step - loss: 0.0012 - acc: 1.0000
# Epoch 114/200
# 10/10 [==============================] - 3s 320ms/step - loss: 0.0024 - acc: 0.9995
# Epoch 115/200
# 10/10 [==============================] - 3s 324ms/step - loss: 0.0018 - acc: 0.9998
# Epoch 116/200
# 10/10 [==============================] - 3s 318ms/step - loss: 0.0037 - acc: 0.9989
# Epoch 117/200
# 10/10 [==============================] - 3s 318ms/step - loss: 0.0013 - acc: 0.9993
# Epoch 118/200
# 10/10 [==============================] - 3s 315ms/step - loss: 0.0027 - acc: 0.9993
# Epoch 119/200
# 10/10 [==============================] - 3s 309ms/step - loss: 0.0019 - acc: 0.9998
# Epoch 120/200
# 10/10 [==============================] - 3s 315ms/step - loss: 0.0050 - acc: 0.9996
# Epoch 121/200
# 10/10 [==============================] - 3s 321ms/step - loss: 0.0021 - acc: 0.9986
# Epoch 122/200
# 10/10 [==============================] - 3s 312ms/step - loss: 0.0059 - acc: 0.9972
# Epoch 123/200
# 10/10 [==============================] - 3s 311ms/step - loss: 0.0076 - acc: 0.9982
# Epoch 124/200
# 10/10 [==============================] - 3s 314ms/step - loss: 0.0019 - acc: 0.9997
# Epoch 125/200
# 10/10 [==============================] - 3s 317ms/step - loss: 0.0016 - acc: 1.0000
# Epoch 126/200
# 10/10 [==============================] - 3s 313ms/step - loss: 0.0060 - acc: 0.9972
# Epoch 127/200
# 10/10 [==============================] - 3s 304ms/step - loss: 0.0039 - acc: 0.9989
# Epoch 128/200
# 10/10 [==============================] - 3s 316ms/step - loss: 3.1683e-04 - acc: 1.0000
# Epoch 129/200
# 10/10 [==============================] - 3s 315ms/step - loss: 0.0010 - acc: 1.0000
# Epoch 130/200
# 10/10 [==============================] - 3s 318ms/step - loss: 0.0019 - acc: 0.9998
# Epoch 131/200
# 10/10 [==============================] - 3s 319ms/step - loss: 0.0021 - acc: 1.0000
# Epoch 132/200
# 10/10 [==============================] - 3s 318ms/step - loss: 9.8527e-04 - acc: 1.0000
# Epoch 133/200
# 10/10 [==============================] - 3s 319ms/step - loss: 0.0013 - acc: 1.0000
# Epoch 134/200
# 10/10 [==============================] - 3s 315ms/step - loss: 1.8756e-04 - acc: 1.0000
# Epoch 135/200
# 10/10 [==============================] - 3s 312ms/step - loss: 0.0023 - acc: 0.9986
# Epoch 136/200
# 10/10 [==============================] - 3s 313ms/step - loss: 0.0036 - acc: 0.9984
# Epoch 137/200
# 10/10 [==============================] - 3s 313ms/step - loss: 0.0086 - acc: 0.9972
# Epoch 138/200
# 10/10 [==============================] - 3s 320ms/step - loss: 0.0032 - acc: 0.9991
# Epoch 139/200
# 10/10 [==============================] - 3s 315ms/step - loss: 6.2110e-04 - acc: 1.0000
# Epoch 140/200
# 10/10 [==============================] - 3s 321ms/step - loss: 0.0016 - acc: 0.9991
# Epoch 141/200
# 10/10 [==============================] - 3s 313ms/step - loss: 0.0013 - acc: 0.9995
# Epoch 142/200
# 10/10 [==============================] - 3s 318ms/step - loss: 0.0021 - acc: 0.9989
# Epoch 143/200
# 10/10 [==============================] - 3s 314ms/step - loss: 0.0010 - acc: 1.0000
# Epoch 144/200
# 10/10 [==============================] - 3s 320ms/step - loss: 0.0030 - acc: 0.9990
# Epoch 145/200
# 10/10 [==============================] - 3s 322ms/step - loss: 0.0039 - acc: 0.9976
# Epoch 146/200
# 10/10 [==============================] - 3s 319ms/step - loss: 4.1898e-04 - acc: 1.0000
# Epoch 147/200
# 10/10 [==============================] - 3s 317ms/step - loss: 0.0035 - acc: 0.9986
# Epoch 148/200
# 10/10 [==============================] - 3s 320ms/step - loss: 0.0021 - acc: 0.9990
# Epoch 149/200
# 10/10 [==============================] - 3s 308ms/step - loss: 0.0017 - acc: 0.9989
# Epoch 150/200
# 10/10 [==============================] - 3s 318ms/step - loss: 0.0046 - acc: 0.9967
# Epoch 151/200
# 10/10 [==============================] - 3s 304ms/step - loss: 0.0020 - acc: 0.9998
# Epoch 152/200
# 10/10 [==============================] - 3s 320ms/step - loss: 0.0207 - acc: 0.9970
# Epoch 153/200
# 10/10 [==============================] - 3s 321ms/step - loss: 0.0055 - acc: 0.9991
# Epoch 154/200
# 10/10 [==============================] - 3s 316ms/step - loss: 0.0062 - acc: 0.9980
# Epoch 155/200
# 10/10 [==============================] - 3s 315ms/step - loss: 0.0256 - acc: 0.9917
# Epoch 156/200
# 10/10 [==============================] - 3s 322ms/step - loss: 0.0253 - acc: 0.9919
# Epoch 157/200
# 10/10 [==============================] - 3s 315ms/step - loss: 0.0291 - acc: 0.9916
# Epoch 158/200
# 10/10 [==============================] - 3s 321ms/step - loss: 0.0243 - acc: 0.9900
# Epoch 159/200
# 10/10 [==============================] - 3s 322ms/step - loss: 0.0311 - acc: 0.9903
# Epoch 160/200
# 10/10 [==============================] - 3s 323ms/step - loss: 0.0133 - acc: 0.9946
# Epoch 161/200
# 10/10 [==============================] - 3s 316ms/step - loss: 0.0100 - acc: 0.9941
# Epoch 162/200
# 10/10 [==============================] - 3s 314ms/step - loss: 0.0040 - acc: 0.9989
# Epoch 163/200
# 10/10 [==============================] - 3s 319ms/step - loss: 0.0213 - acc: 0.9877
# Epoch 164/200
# 10/10 [==============================] - 3s 315ms/step - loss: 0.0189 - acc: 0.9926
# Epoch 165/200
# 10/10 [==============================] - 3s 317ms/step - loss: 0.0065 - acc: 0.9970
# Epoch 166/200
# 10/10 [==============================] - 3s 319ms/step - loss: 0.0095 - acc: 0.9954
# Epoch 167/200
# 10/10 [==============================] - 3s 310ms/step - loss: 0.0013 - acc: 0.9998
# Epoch 168/200
# 10/10 [==============================] - 3s 309ms/step - loss: 0.0088 - acc: 0.9972
# Epoch 169/200
# 10/10 [==============================] - 3s 315ms/step - loss: 0.0053 - acc: 0.9993
# Epoch 170/200
# 10/10 [==============================] - 3s 320ms/step - loss: 0.0032 - acc: 1.0000
# Epoch 171/200
# 10/10 [==============================] - 3s 318ms/step - loss: 0.0111 - acc: 0.9976
# Epoch 172/200
# 10/10 [==============================] - 3s 320ms/step - loss: 0.0041 - acc: 0.9986
# Epoch 173/200
# 10/10 [==============================] - 3s 318ms/step - loss: 6.2940e-04 - acc: 0.9998
# Epoch 174/200
# 10/10 [==============================] - 3s 312ms/step - loss: 0.0229 - acc: 0.9883
# Epoch 175/200
# 10/10 [==============================] - 3s 318ms/step - loss: 0.0022 - acc: 0.9995
# Epoch 176/200
# 10/10 [==============================] - 3s 309ms/step - loss: 0.0052 - acc: 0.9978
# Epoch 177/200
# 10/10 [==============================] - 3s 312ms/step - loss: 0.0015 - acc: 0.9998
# Epoch 178/200
# 10/10 [==============================] - 3s 320ms/step - loss: 0.0064 - acc: 0.9982
# Epoch 179/200
# 10/10 [==============================] - 3s 308ms/step - loss: 0.0045 - acc: 0.9983
# Epoch 180/200
# 10/10 [==============================] - 3s 323ms/step - loss: 0.0015 - acc: 1.0000
# Epoch 181/200
# 10/10 [==============================] - 3s 313ms/step - loss: 0.0027 - acc: 1.0000
# Epoch 182/200
# 10/10 [==============================] - 3s 309ms/step - loss: 7.9384e-04 - acc: 1.0000
# Epoch 183/200
# 10/10 [==============================] - 3s 312ms/step - loss: 7.7837e-04 - acc: 1.0000
# Epoch 184/200
# 10/10 [==============================] - 3s 321ms/step - loss: 2.7943e-04 - acc: 1.0000
# Epoch 185/200
# 10/10 [==============================] - 3s 316ms/step - loss: 0.0021 - acc: 0.9993
# Epoch 186/200
# 10/10 [==============================] - 3s 317ms/step - loss: 9.1548e-04 - acc: 0.9991
# Epoch 187/200
# 10/10 [==============================] - 3s 313ms/step - loss: 0.0137 - acc: 0.9941
# Epoch 188/200
# 10/10 [==============================] - 3s 311ms/step - loss: 0.0020 - acc: 0.9996
# Epoch 189/200
# 10/10 [==============================] - 3s 316ms/step - loss: 9.6506e-04 - acc: 1.0000
# Epoch 190/200
# 10/10 [==============================] - 3s 308ms/step - loss: 0.0032 - acc: 0.9997
# Epoch 191/200
# 10/10 [==============================] - 3s 315ms/step - loss: 9.3220e-04 - acc: 1.0000
# Epoch 192/200
# 10/10 [==============================] - 3s 314ms/step - loss: 0.0027 - acc: 0.9972
# Epoch 193/200
# 10/10 [==============================] - 3s 306ms/step - loss: 2.8896e-04 - acc: 1.0000
# Epoch 194/200
# 10/10 [==============================] - 3s 319ms/step - loss: 0.0024 - acc: 0.9981
# Epoch 195/200
# 10/10 [==============================] - 3s 318ms/step - loss: 0.0097 - acc: 0.9972
# Epoch 196/200
# 10/10 [==============================] - 3s 315ms/step - loss: 0.0079 - acc: 0.9963
# Epoch 197/200
# 10/10 [==============================] - 3s 320ms/step - loss: 5.0670e-04 - acc: 1.0000
# Epoch 198/200
# 10/10 [==============================] - 3s 318ms/step - loss: 7.3227e-04 - acc: 1.0000
# Epoch 199/200
# 10/10 [==============================] - 3s 314ms/step - loss: 6.4458e-04 - acc: 1.0000
# Epoch 200/200
# 10/10 [==============================] - 3s 311ms/step - loss: 2.2237e-04 - acc: 1.0000
# Learning TIme : 637.65

# %%
score = model.evaluate(x=X_test,
                       y=Y_test,
                       verbose=1)
print("Final Loss : {:.2f}".format(score[0]))
print("Final Accuracy : {:.2f}".format(score[1]))
# Out:
# 7/7 [==============================] - 1s 40ms/step - loss: 1.0335 - acc: 0.8650
# Final Loss : 1.03
# Final Accuracy : 0.87

# %%
total = len(X_test)
pick = random.sample(range(0,total),1)
print(pick)

plt.imshow(X_test[pick].reshape(RES, RES, 3))
img = X_test[pick].reshape(1, RES, RES, 3)
pred = model.predict(img)

print("Label :", Y_test[pick])
print("Pred :", pred)
# Out:
# [134]
# Label : [1.]
# Pred : [[0.7094407]]
